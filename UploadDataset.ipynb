# %% [markdown]
# <a href="https://colab.research.google.com/github/Er-Manav/Indian-Currency-Recognition/blob/master/UploadDataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
my_file=files.upload()
# Out:
#      <input type="file" id="files-8603b7bf-4030-4686-97ad-eccefeab4c39" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8603b7bf-4030-4686-97ad-eccefeab4c39">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %% [markdown]
# Importing required libraries

# %%
import os
import pandas as pd
cred = pd.read_json("kaggle.json",lines=True)
os.environ['KAGGLE_USERNAME'] = cred.iloc[0][0]
os.environ['KAGGLE_KEY'] = cred.iloc[0][1]
# %reload_ext autoreload
# %autoreload 2
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore")

# %% [markdown]
# Downloading Data From Kaggle

# %%
# !kaggle datasets download -d shobhit18th/indian-currency-notes
# Out:
# ...
#  97% 281M/290M [00:04<00:00, 57.1MB/s]
# 100% 290M/290M [00:04<00:00, 73.1MB/s]

# %% [markdown]
# Unzipping the *datasets*

# %%
# !unzip "*.zip"
# Out:
# Archive:  indian-currency-notes.zip
#   inflating: indian_currency_new/training/10/0.jpg
#   inflating: indian_currency_new/training/10/1.jpg
#   inflating: indian_currency_new/training/10/10.jpg
#   inflating: indian_currency_new/training/10/100.jpg
#   inflating: indian_currency_new/training/10/102.jpg
#   inflating: indian_currency_new/training/10/103.jpg
#   inflating: indian_currency_new/training/10/11.jpg
#   inflating: indian_currency_new/training/10/12.jpg
#   inflating: indian_currency_new/training/10/13.jpg
#   inflating: indian_currency_new/training/10/14.jpg
#   inflating: indian_currency_new/training/10/17.jpg
#   inflating: indian_currency_new/training/10/18.jpg
#   inflating: indian_currency_new/training/10/19.jpg
#   inflating: indian_currency_new/training/10/2.jpg
#   inflating: indian_currency_new/training/10/20.jpg
#   inflating: indian_currency_new/training/10/21.jpg
#   inflating: indian_currency_new/training/10/22.jpg
# ...

# %%
# !mv "/content/indian_currency_new/training" "/content/Indian_Currency"

# %%
# !mv "/content/Indian_Currency/training/10/200.jpg" "/content/Indian_Currency/training/200"

# %% [markdown]
# Renaming the images for creating testdataset

# %%
for i in os.listdir("/content/Indian_Currency/training"):
  if i!=".ipynb_checkpoints":
    path = r'/content/indian_currency_new/validation/'+i
    files = os.listdir(path)
    os.getcwd()
    for index, file in enumerate(files):
        os.rename(os.path.join(path, file), os.path.join(path, str(index)+i+'.jpg'))

# %% [markdown]
# Copying the images

# %%
# !gsutil cp -r "/content/indian_currency_new/validation/10/*.jpg" "/content/Indian_Currency/test_data"

# %%
# !gsutil cp -r "/content/indian_currency_new/validation/20/*.jpg" "/content/Indian_Currency/test_data"

# %%
# !gsutil cp -r "/content/indian_currency_new/validation/50/*.jpg" "/content/Indian_Currency/test_data"

# %%
# !gsutil cp -r "/content/indian_currency_new/validation/100/*.jpg" "/content/Indian_Currency/test_data"
# Out:
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.

# %%
# !gsutil cp -r "/content/indian_currency_new/validation/200/*.jpg" "/content/Indian_Currency/test_data"
# Out:
# Copying file:///content/indian_currency_new/validation/200/6200.jpg...
# Copying file:///content/indian_currency_new/validation/200/2200.jpg...
# Copying file:///content/indian_currency_new/validation/200/8200.jpg...
# Copying file:///content/indian_currency_new/validation/200/16200.jpg...
# / [4 files][  2.1 MiB/  2.1 MiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying file:///content/indian_currency_new/validation/200/11200.jpg...
# Copying file:///content/indian_currency_new/validation/200/17200.jpg...
# Copying file:///content/indian_currency_new/validation/200/22200.jpg...
# Copying file:///content/indian_currency_new/validation/200/14200.jpg...
# Copying file:///content/indian_currency_new/validation/200/18200.jpg...
# ...

# %%
# !gsutil cp -r "/content/indian_currency_new/validation/500/*.jpg" "/content/Indian_Currency/test_data"
# Out:
# Copying file:///content/indian_currency_new/validation/500/18500.jpg...
# Copying file:///content/indian_currency_new/validation/500/16500.jpg...
# Copying file:///content/indian_currency_new/validation/500/21500.jpg...
# Copying file:///content/indian_currency_new/validation/500/7500.jpg...
# / [4 files][276.8 KiB/276.8 KiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying file:///content/indian_currency_new/validation/500/14500.jpg...
# Copying file:///content/indian_currency_new/validation/500/9500.jpg...
# Copying file:///content/indian_currency_new/validation/500/15500.jpg...
# Copying file:///content/indian_currency_new/validation/500/20500.jpg...
# Copying file:///content/indian_currency_new/validation/500/23500.jpg...
# ...

# %%
# !gsutil cp -r "/content/indian_currency_new/validation/2000/*.jpg" "/content/Indian_Currency/test_data"
# Out:
# Copying file:///content/indian_currency_new/validation/2000/22000.jpg...
# Copying file:///content/indian_currency_new/validation/2000/232000.jpg...
# Copying file:///content/indian_currency_new/validation/2000/112000.jpg...
# Copying file:///content/indian_currency_new/validation/2000/152000.jpg...
# / [4 files][  1.0 MiB/  1.0 MiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying file:///content/indian_currency_new/validation/2000/62000.jpg...
# Copying file:///content/indian_currency_new/validation/2000/172000.jpg...
# Copying file:///content/indian_currency_new/validation/2000/122000.jpg...
# Copying file:///content/indian_currency_new/validation/2000/82000.jpg...
# Copying file:///content/indian_currency_new/validation/2000/142000.jpg...
# ...

# %%
# !gsutil cp -r "/content/indian_currency_new/validation/No Money/*.jpg" "/content/Indian_Currency/test_data"
# Out:
# Copying file:///content/indian_currency_new/validation/No Money/16No Money.jpg...
# Copying file:///content/indian_currency_new/validation/No Money/19No Money.jpg...
# Copying file:///content/indian_currency_new/validation/No Money/20No Money.jpg...
# Copying file:///content/indian_currency_new/validation/No Money/14No Money.jpg...
# / [4 files][529.4 KiB/529.4 KiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying file:///content/indian_currency_new/validation/No Money/17No Money.jpg...
# Copying file:///content/indian_currency_new/validation/No Money/6No Money.jpg...
# Copying file:///content/indian_currency_new/validation/No Money/1No Money.jpg...
# Copying file:///content/indian_currency_new/validation/No Money/4No Money.jpg...
# ...

# %% [markdown]
# Uploading the Currency Dataset

# %%
# !kaggle datasets init -p /content/Indian_Currency
# Out:
# Data package template written to: /content/Indian_Currency/dataset-metadata.json

# %%
# !kaggle datasets create -p /content/Indian_Currency -r tar
# Out:
# Starting upload for file test_data.tar
# ...
# 100% 61.9M/61.9M [00:03<00:00, 20.4MB/s]
# Upload successful: test_data.tar (62MB)
# Starting upload for file .ipynb_checkpoints.tar
# 100% 10.0k/10.0k [00:02<00:00, 4.14kB/s]
# Upload successful: .ipynb_checkpoints.tar (10KB)
# Starting upload for file training.tar
# 100% 265M/265M [00:04<00:00, 62.7MB/s]
# Upload successful: training.tar (265MB)
# Your private Dataset is being created. Please check progress at https://www.kaggle.com/ermanav/IndianCurrencyDataset
